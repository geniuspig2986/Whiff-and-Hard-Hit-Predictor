# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display plots inline
# %matplotlib inline

# %%
# Load your dataset
df = pd.read_csv("statcast_pitch_swing_data_20240402_20241030_with_arm_angle.csv")

# Take a quick look
print(df.shape)
df.head()
# Out:
# (701557, 113)
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2024-04-02           95.0          -2.01           5.22
# 1         CH  2024-04-02           88.5          -2.09           4.95
# 2         SI  2024-04-02           95.0          -2.02           5.12
# 3         KC  2024-04-02           80.8          -3.13           5.61
# 4         FF  2024-04-02           95.4          -1.95           5.12
#
#        player_name  batter  pitcher     events    description  ...  \
# 0  Rocchio, Brayan  677587   622491     single  hit_into_play  ...
# 1  Rocchio, Brayan  677587   622491        NaN           foul  ...
# 2  Rocchio, Brayan  677587   622491        NaN  called_strike  ...
# 3   Rizzo, Anthony  519203   668678  field_out  hit_into_play  ...
# 4   Hedges, Austin  595978   622491  strikeout       foul_tip  ...
#
#    n_thruorder_pitcher  n_priorpa_thisgame_player_at_bat  \
# 0                    3                                 2
# ...

# %%
# Select key columns for batters
columns = [
    'game_date', 'player_name', 'events', 'launch_speed', 'launch_angle',
    'hit_distance_sc', 'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle',
    'woba_value', 'woba_denom', 'game_year'
]
df = df[columns]

# Drop missing or null rows
df = df.dropna(subset=['player_name', 'launch_speed', 'events'])

# Convert dates to datetime
df['game_date'] = pd.to_datetime(df['game_date'])
